# %%
with open("DANIA_17__Stave.jsf", 'rb') as f:
    # arr=[]
    # while f:
    #     number= (list(f.read(387)))
    #     line = ''.join(str(e) for e in number)
    #     print(line + '\n')
    #     arr.append
    first_line = (f.readline())
    print(first_line)
    
    # print(arr)
  


            
# read_file()
# Out:
# b'\x01\x16\x10\x00\xb6\x00\x02\x00\x00\x00\x00\x00\xf0\x06\x00\x00&\x00\x00\x00\x01\x00\x00\x00%n\x19\x00\x00\xdc2\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x008\x00\x00\x00P\xc3\x00\x00\x15\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\xfe\xff\xff\xff{\xff\xff\xff\xe8\x03\x00\x00\xe8\x03\x00\x00\xe8\x03\x00\x00\xe8\x03\x00\x00\xb8\x01\x00\x00\xb8\x01\x00\x00\xb8\x01\x00\x00\xb8\x01\x00\x00\x02\x0b\x00\x00\x02\x0b\x00\x00\x02\x0b\x00\x00\x02\x0b\x00\x002205B_SS850__80BW_1_50MS.spf\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\
# ...

# %%
len('')
# Out:
# 387
